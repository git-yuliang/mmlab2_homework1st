# %% [markdown]
# # 三角板目标检测-训练
#
# 同济子豪兄 2023-4-3

# %% [markdown]
# ## 进入mmdetection主目录

# %%
path0 = '/home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content/'
os.chdir(path0)

# %%
# import os
# #os.chdir(path0 + 'mmdetection')
# os.chdir(path0 + 'mmpose')

# %%
# # 删掉原有的 mmdetection 文件夹（如有）
# !rm -rf mmdetection

# # 从 github 上下载最新的 mmdetection 源代码
# !git clone https://github.com/open-mmlab/mmdetection.git -b 3.x

# %%
# 进入主目录
import os
os.chdir('mmdetection')
# !pip install -v -e .
# Out:
# Using pip 23.1.2 from /home/liangyu/miniconda3/envs/mmlab2/lib/python3.9/site-packages/pip (python 3.9)
# WARNING: Ignoring invalid distribution -orch (/home/liangyu/miniconda3/envs/mmlab2/lib/python3.9/site-packages)
# Obtaining file:///home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content/mmdetection
#   Preparing metadata (setup.py) ...   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-xc8pgc6p/mmdet.egg-info
#   writing /tmp/pip-pip-egg-info-xc8pgc6p/mmdet.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-xc8pgc6p/mmdet.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-xc8pgc6p/mmdet.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-xc8pgc6p/mmdet.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-xc8pgc6p/mmdet.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-xc8pgc6p/mmdet.egg-info/SOURCES.txt'
# ...

# %%
# 检查 mmpose
import mmdet
print('mmdetection版本', mmdet.__version__)

# 检查 Pytorch
import torch, torchvision
print('Pytorch 版本', torch.__version__)
print('CUDA 是否可用',torch.cuda.is_available())
# Out:
# mmdetection版本 3.0.0
# Pytorch 版本 1.10.1+cu113
# CUDA 是否可用 False

# %%
#!pip show torch

# %%
pwd
# Out:
# '/home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content/mmdetection'

# %% [markdown]
# ## 目标检测算法：Faster R CNN

# %%
# 为了防止找不到，所以都直接使用了一个绝对目录
# !python tools/train.py --work-dir ../work_dir/rtmpose_tiny_ear ../rtmdet_tiny_ear.py
# Out:
# 06/05 10:38:52 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 | packaged by conda-forge | (main, Feb  1 2023, 21:39:03) [GCC 11.3.0]
#     CUDA available: False
#     numpy_random_seed: 777132029
#     GCC: gcc (Ubuntu 12.2.0-3ubuntu1) 12.2.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
# ...

# %% [markdown]
# ## 目标检测算法：RTMDet

# %%
# # 建议在命令行中运行
# !python tools/train.py data/rtmdet_tiny_triangle.py

# %%
pwd
# Out:
# '/home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content/mmdetection'

# %% [markdown]
# ## 在`work_dirs`目录下，查看训练日志和训练得到的模型权重文件

# %% [markdown]
# ## 测试集上评估模型精度

# %%
# !python tools/test.py ../rtmdet_tiny_ear.py \
                      ../work_dir/rtmpose_tiny_ear/epoch_200.pth
# Out:
# 06/05 12:21:59 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 | packaged by conda-forge | (main, Feb  1 2023, 21:39:03) [GCC 11.3.0]
#     CUDA available: False
#     numpy_random_seed: 1055895706
#     GCC: gcc (Ubuntu 12.2.0-3ubuntu1) 12.2.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
# ...
