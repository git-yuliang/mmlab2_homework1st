# %% [markdown]
# # RTMPOSE-训练
#
# liangyu 20230605

# %% [markdown]
# ## 进入mmPOSE主目录

# %%
import os
path0 = '/home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content1/'
os.chdir(path0)

# %%
pwd
# Out:
# '/home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content1'

# %%
# 删掉原有的 mmpose 文件夹（如有）
# !rm -rf mmpose

# %%
# 从 github 上下载最新的 mmpose 源代码
# !git clone https://github.com/open-mmlab/mmpose.git -b tutorial2023
# Out:
# Cloning into 'mmpose'...
# remote: Enumerating objects: 27394, done.
# remote: Counting objects: 100% (1217/1217), done.
# remote: Compressing objects: 100% (624/624), done.
# remote: Total 27394 (delta 655), reused 1003 (delta 574), pack-reused 26177
# Receiving objects: 100% (27394/27394), 30.06 MiB | 14.28 MiB/s, done.
# Resolving deltas: 100% (19351/19351), done.

# %%
pwd
# Out:
# '/home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content1'

# %%
# # 删掉原有的 mmpose 文件夹（如有）
# !rm -rf mmpose

# # 从 github 上下载最新的 mmpose 源代码
# !git clone https://github.com/open-mmlab/mmpose.git -b tutorial2023

# 进入主目录
import os
os.chdir('mmpose')

# !mim install -e .
# Out:
# WARNING: Ignoring invalid distribution -orch (/home/liangyu/miniconda3/envs/mmlab2/lib/python3.9/site-packages)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.10.0/index.html
# Obtaining file:///home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content1/mmpose
#   Preparing metadata (setup.py) ... done
#   WARNING: Ignoring invalid distribution -orch (/home/liangyu/miniconda3/envs/mmlab2/lib/python3.9/site-packages)
# ...
# WARNING: Ignoring invalid distribution -orch (/home/liangyu/miniconda3/envs/mmlab2/lib/python3.9/site-packages)
# ...
#   Running setup.py develop for mmpose
# WARNING: Ignoring invalid distribution -orch (/home/liangyu/miniconda3/envs/mmlab2/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/home/liangyu/miniconda3/envs/mmlab2/lib/python3.9/site-packages)
# ...

# %%
# 检查 mmpose
import mmpose
print('mmpose版本', mmpose.__version__)

# 检查 Pytorch
import torch, torchvision
print('Pytorch 版本', torch.__version__)
print('CUDA 是否可用',torch.cuda.is_available())
# Out:
# mmpose版本 1.0.0
# Pytorch 版本 1.10.1+cu113
# CUDA 是否可用 False

# %%
pwd
# Out:
# '/home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content1/mmpose'

# %% [markdown]
# ## 目标检测算法：rtmpose

# %%
# 为了防止找不到，所以都直接使用了一个绝对目录
# !python tools/train.py --work-dir ../work_dir/rtmpose-s-ear ../rtmpose-s-ear.py
# Out:
# 06/05 11:43:18 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 | packaged by conda-forge | (main, Feb  1 2023, 21:39:03) [GCC 11.3.0]
#     CUDA available: False
#     numpy_random_seed: 21
#     GCC: gcc (Ubuntu 12.2.0-3ubuntu1) 12.2.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
# ...

# %% [markdown]
# ## 目标检测算法：RTMDet

# %%
# # 建议在命令行中运行
#!python tools/train.py data/rtmdet_tiny_triangle.py

# %% [markdown]
# ## 在`work_dirs`目录下，查看训练日志和训练得到的模型权重文件

# %%
pwd
# Out:
# '/home/liangyu/code/mmlab2/2023AI/0601/ear_test/MMPosehomework/content1/mmpose'

# %% [markdown]
# ## 测试集上评估模型精度

# %%
# !python tools/test.py ../rtmpose-s-ear.py \
                      ../work_dir/rtmpose-s-ear/epoch_300.pth
# Out:
# 06/05 16:47:47 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 | packaged by conda-forge | (main, Feb  1 2023, 21:39:03) [GCC 11.3.0]
#     CUDA available: False
#     numpy_random_seed: 21
#     GCC: gcc (Ubuntu 12.2.0-3ubuntu1) 12.2.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
# ...
